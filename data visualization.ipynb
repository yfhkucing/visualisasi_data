# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel(
    'UN_MigFlow_All_CountryFiles/Canada.xlsx',
    sheet_name="Canada by Citizenship",
    skiprows=range(20),
    skipfooter=2
    )

data.pop('Type')
data.pop('Coverage')
# Out:
# 0      Foreigners
# 1      Foreigners
# 2      Foreigners
# 3      Foreigners
# 4      Foreigners
#           ...
# 190    Foreigners
# 191    Foreigners
# 192    Foreigners
# 193    Foreigners
# 194    Foreigners
# Name: Coverage, Length: 195, dtype: object

# %%
data
# Out:
#              OdName  AREA AreaName   REG             RegName  DEV  \
# 0       Afghanistan   935     Asia  5501       Southern Asia  902
# 1           Albania   908   Europe   925     Southern Europe  901
# 2           Algeria   903   Africa   912     Northern Africa  902
# 3    American Samoa   909  Oceania   957           Polynesia  902
# 4           Andorra   908   Europe   925     Southern Europe  901
# ..              ...   ...      ...   ...                 ...  ...
# 190        Viet Nam   935     Asia   920  South-Eastern Asia  902
# 191  Western Sahara   903   Africa   912     Northern Africa  902
# 192           Yemen   935     Asia   922        Western Asia  902
# 193          Zambia   903   Africa   910      Eastern Africa  902
# 194        Zimbabwe   903   Africa   910      Eastern Africa  902
#
#                 DevName  1980  1981  1982  ...  2004  2005  2006  2007  2008  \
# 0    Developing regions    16    39    39  ...  2978  3436  3009  2652  2111
# ...

# %%
df = data.set_index('OdName')
years = list(map(str, range(1980,2014)))
df.loc['Zimbabwe',years].plot(kind='line')
plt.title("aaaa")
plt.ylabel("bb")
plt.xlabel("cc")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11308\702887892.py in <module>
#       1 df = data.set_index('OdName')
#       2 years = list(map(str, range(1980,2014)))
# ----> 3 df.loc['Zimbabwe',years].plot(kind='line')
#       4 plt.title("aaaa")
#       5 plt.ylabel("bb")
#
# c:\Users\hp\Desktop\IT_stuff_idk\visualisasi_data\.venv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# c:\Users\hp\Desktop\IT_stuff_idk\visualisasi_data\.venv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
# ...
